# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.DataFrame([[0.53,0.40, 0.65, 0.63],[0.70,0.66, 0.80, 0.88],[0.74,0.57, 0.94, 0.86],[ 0.51,0.50, 0.56, 0.53],[0.40,0.72, 0.85, 0.90],
[0.76,0.61, 0.74, 0.82],[0.88,0.76, 0.89, 0.88],[0.92,0.74, 0.91, 0.90 ]],index=['Imago', 'MolVec', 'Osra', 'DECIMER','MolMiner', 'MICER', 'MolScribe','Image2InChI'],
                  columns=('BMS','JPO', 'CLEF', 'UOB'))

plt.figure()
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#annot: 默认为False，为True的话，会在格子上显示数字；fmt设置小数点后几位
sns.heatmap(data,annot=True,vmax=1.0, vmin=0.3,cmap='Reds',annot_kws={'size':19,'weight':'bold', 'color':'black'},fmt='.2f')
plt.show()
# InChI acc

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.DataFrame([[0.50,0.26, 0.60, 0.36],[0.52,0.32, 0.83, 0.49],[0.57, 0.20, 0.22, 0.27],[0.53,0.29, 0.51, 0.57],[ 0.46,0.35, 0.87, 0.93,],
[0.69,0.46, 0.79, 0.74],[ 0.90,0.48, 0.85, 0.82],[ 0.93,0.47, 0.86, 0.94]],index=['Imago', 'MolVec', 'Osra', 'DECIMER','MolMiner', 'MICER', 'MolScribe','Image2InChI'],
                   columns=('BMS','JPO', 'CLEF', 'UOB'))

plt.figure()
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#annot: 默认为False，为True的话，会在格子上显示数字；fmt设置小数点后几位
sns.heatmap(data,annot=True,vmax=1.0, vmin=0.3,cmap='Reds',annot_kws={'size':19,'weight':'bold', 'color':'black'},fmt='.2f')
plt.show()
# MCS acc

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.DataFrame([[0.68,0.54, 0.62, 0.64],[0.69,0.41, 0.64, 0.61],[0.72,0.30, 0.39, 0.44],[ 0.60,0.32, 0.57, 0.62],[0.51,0.42, 0.83, 0.94],
[0.71,0.51, 0.81, 0.77],[0.91,0.57, 0.86, 0.85],[0.96,0.60, 0.87, 0.96]],index=['Imago', 'MolVec', 'Osra', 'DECIMER','MolMiner', 'MICER', 'MolScribe','Image2InChI'],
                  columns=('BMS','JPO', 'CLEF', 'UOB'))

plt.figure()
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#annot: 默认为False，为True的话，会在格子上显示数字；fmt设置小数点后几位
sns.heatmap(data,annot=True,vmax=1.0, vmin=0.3,cmap='Reds',annot_kws={'size':19,'weight':'bold', 'color':'black'},fmt='.2f')
plt.show()
# LCS acc
